# %%
# packages
import os
import joblib
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import subplots
import statsmodels.api as sm
from sklearn.model_selection import train_test_split 
from sklearn.ensemble import GradientBoostingRegressor as GBR
from sklearn.model_selection import GridSearchCV

# set seed
seed = 5151

# %% [markdown]
# ### You'll need the California housing data (CAhousing.csv) to complete this exercise. Your goal is to predict the median house value.

# %%
CAhousing = pd.read_csv('data/CAhousing.csv')
CAhousing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -120.45     34.66                 7.0       3329.0           504.0
# 1    -114.64     34.83                10.0       2502.0           573.0
# 2    -117.24     32.74                43.0       2216.0           375.0
# 3    -122.43     37.76                52.0       3771.0          1017.0
# 4    -118.02     34.13                34.0       1966.0           319.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0      1462.0       452.0         4.7875            198300.0      NEAR OCEAN
# 1      1152.0       481.0         1.7062             86800.0          INLAND
# 2       918.0       388.0         5.5289            297700.0      NEAR OCEAN
# 3      1575.0       921.0         3.5655            427300.0        NEAR BAY
# 4       980.0       297.0         7.7307            429000.0          INLAND

# %%
CAhousing.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# ocean_proximity        object
# dtype: object

# %%
CAhousing.shape
# Out:
# (15480, 10)

# %% [markdown]
# ### There is a single categorical variable in this dataset that we will convert to a series of binary variables.

# %%
CAhousing['ocean_proximity'].value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     6857
# INLAND        4933
# NEAR OCEAN    1974
# NEAR BAY      1712
# ISLAND           4
# Name: count, dtype: int64

# %%
# create binary variables for levels which have enough records, using '<1H OCEAN' as base.
CAhousing['ocean_prox_inland'] = (CAhousing.ocean_proximity == 'INLAND').astype(int)
CAhousing['ocean_prox_nearocean'] = (CAhousing.ocean_proximity == 'NEAR OCEAN').astype(int)
CAhousing['ocean_prox_nearbay'] = (CAhousing.ocean_proximity == 'NEAR BAY').astype(int)

# check for intended outcome
print(CAhousing['ocean_prox_inland'].value_counts())
print(CAhousing['ocean_prox_nearocean'].value_counts())
print(CAhousing['ocean_prox_nearbay'].value_counts())
# Out:
# ocean_prox_inland
# 0    10547
# 1     4933
# Name: count, dtype: int64
# ocean_prox_nearocean
# 0    13506
# 1     1974
# Name: count, dtype: int64
# ocean_prox_nearbay
# 0    13768
# 1     1712
# Name: count, dtype: int64

# %%
indep_vars = ['longitude', 'latitude', 'housing_median_age', 'total_rooms', 
              'total_bedrooms', 'population', 'households', 'median_income', 
              'ocean_prox_inland', 'ocean_prox_nearocean', 'ocean_prox_nearbay']

X = CAhousing[indep_vars]
y = CAhousing['median_house_value']

# %%
X_train, X_test, y_train, y_test, Train, Test = train_test_split(X, y, CAhousing, 
                                                                 random_state = seed, 
                                                                 test_size = 0.33, 
                                                                 shuffle = True)

# %%
X_train.corr().style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <style type="text/css">
# #T_a963f_row0_col0, #T_a963f_row1_col1, #T_a963f_row2_col2, #T_a963f_row3_col3, #T_a963f_row4_col4, #T_a963f_row5_col5, #T_a963f_row6_col6, #T_a963f_row7_col7, #T_a963f_row8_col8, #T_a963f_row9_col9, #T_a963f_row10_col10 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_a963f_row0_col1, #T_a963f_row1_col0 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_a963f_row0_col2, #T_a963f_row2_col0 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_a963f_row0_col3, #T_a963f_row3_col0 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_a963f_row0_col4, #T_a963f_row4_col0 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_a963f_row0_col5, #T_a963f_row5_col0 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_a963f_row0_col6, #T_a963f_row6_col0, #T_a963f_row7_col10, #T_a963f_row10_col7 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_a963f_row0_col7, #T_a963f_row3_col9, #T_a963f_row7_col0, #T_a963f_row9_col3 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_a963f_row0_col8, #T_a963f_row1_col4, #T_a963f_row4_col1, #T_a963f_row5_col10, #T_a963f_row8_col0, #T_a963f_row10_col5 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_a963f_row0_col9, #T_a963f_row9_col0 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_a963f_row0_col10, #T_a963f_row10_col0 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_a963f_row1_col2, #T_a963f_row2_col1, #T_a963f_row2_col9, #T_a963f_row3_col8, #T_a963f_row8_col3, #T_a963f_row9_col2 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_a963f_row1_col3, #T_a963f_row3_col1 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_a963f_row1_col5, #T_a963f_row5_col1 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_a963f_row1_col6, #T_a963f_row6_col1 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_a963f_row1_col7, #T_a963f_row7_col1 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_a963f_row1_col8, #T_a963f_row8_col1 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_a963f_row1_col9, #T_a963f_row9_col1 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_a963f_row1_col10, #T_a963f_row10_col1 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_a963f_row2_col3, #T_a963f_row3_col2 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_a963f_row2_col4, #T_a963f_row4_col2 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_a963f_row2_col5, #T_a963f_row5_col2 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_a963f_row2_col6, #T_a963f_row6_col2 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_a963f_row2_col7, #T_a963f_row7_col2, #T_a963f_row9_col10, #T_a963f_row10_col9 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_a963f_row2_col8, #T_a963f_row7_col8, #T_a963f_row8_col2, #T_a963f_row8_col7 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_a963f_row2_col10, #T_a963f_row10_col2 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# #T_a963f_row3_col4, #T_a963f_row4_col3 {
#   background-color: #c12b30;
#   color: #f1f1f1;
# }
# #T_a963f_row3_col5, #T_a963f_row5_col3 {
#   background-color: #cc403a;
#   color: #f1f1f1;
# }
# #T_a963f_row3_col6, #T_a963f_row6_col3 {
#   background-color: #c32e31;
#   color: #f1f1f1;
# }
# #T_a963f_row3_col7, #T_a963f_row7_col3 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_a963f_row3_col10, #T_a963f_row5_col8, #T_a963f_row8_col5, #T_a963f_row10_col3 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_a963f_row4_col5, #T_a963f_row5_col4 {
#   background-color: #c83836;
#   color: #f1f1f1;
# }
# #T_a963f_row4_col6, #T_a963f_row6_col4 {
#   background-color: #b70d28;
#   color: #f1f1f1;
# }
# #T_a963f_row4_col7, #T_a963f_row4_col8, #T_a963f_row5_col9, #T_a963f_row7_col4, #T_a963f_row8_col4, #T_a963f_row9_col5 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_a963f_row4_col9, #T_a963f_row5_col7, #T_a963f_row6_col9, #T_a963f_row7_col5, #T_a963f_row9_col4, #T_a963f_row9_col6 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_a963f_row4_col10, #T_a963f_row6_col10, #T_a963f_row10_col4, #T_a963f_row10_col6 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_a963f_row5_col6, #T_a963f_row6_col5 {
#   background-color: #c43032;
#   color: #f1f1f1;
# }
# #T_a963f_row6_col7, #T_a963f_row7_col6 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_a963f_row6_col8, #T_a963f_row8_col6 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_a963f_row7_col9, #T_a963f_row9_col7 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_a963f_row8_col9, #T_a963f_row9_col8 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_a963f_row8_col10, #T_a963f_row10_col8 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# </style>
# <table id="T_a963f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a963f_level0_col0" class="col_heading level0 col0" >longitude</th>
#       <th id="T_a963f_level0_col1" class="col_heading level0 col1" >latitude</th>
#       <th id="T_a963f_level0_col2" class="col_heading level0 col2" >housing_median_age</th>
#       <th id="T_a963f_level0_col3" class="col_heading level0 col3" >total_rooms</th>
#       <th id="T_a963f_level0_col4" class="col_heading level0 col4" >total_bedrooms</th>
#       <th id="T_a963f_level0_col5" class="col_heading level0 col5" >population</th>
#       <th id="T_a963f_level0_col6" class="col_heading level0 col6" >households</th>
#       <th id="T_a963f_level0_col7" class="col_heading level0 col7" >median_income</th>
#       <th id="T_a963f_level0_col8" class="col_heading level0 col8" >ocean_prox_inland</th>
#       <th id="T_a963f_level0_col9" class="col_heading level0 col9" >ocean_prox_nearocean</th>
#       <th id="T_a963f_level0_col10" class="col_heading level0 col10" >ocean_prox_nearbay</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a963f_level0_row0" class="row_heading level0 row0" >longitude</th>
#       <td id="T_a963f_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_a963f_row0_col1" class="data row0 col1" >-0.924779</td>
#       <td id="T_a963f_row0_col2" class="data row0 col2" >-0.118552</td>
#       <td id="T_a963f_row0_col3" class="data row0 col3" >0.044445</td>
#       <td id="T_a963f_row0_col4" class="data row0 col4" >0.067878</td>
#       <td id="T_a963f_row0_col5" class="data row0 col5" >0.095517</td>
#       <td id="T_a963f_row0_col6" class="data row0 col6" >0.056249</td>
#       <td id="T_a963f_row0_col7" class="data row0 col7" >-0.001915</td>
#       <td id="T_a963f_row0_col8" class="data row0 col8" >-0.068406</td>
#       <td id="T_a963f_row0_col9" class="data row0 col9" >0.047632</td>
#       <td id="T_a963f_row0_col10" class="data row0 col10" >-0.471177</td>
#     </tr>
#     <tr>
#       <th id="T_a963f_level0_row1" class="row_heading level0 row1" >latitude</th>
#       <td id="T_a963f_row1_col0" class="data row1 col0" >-0.924779</td>
#       <td id="T_a963f_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_a963f_row1_col2" class="data row1 col2" >0.017276</td>
#       <td id="T_a963f_row1_col3" class="data row1 col3" >-0.034301</td>
#       <td id="T_a963f_row1_col4" class="data row1 col4" >-0.064393</td>
#       <td id="T_a963f_row1_col5" class="data row1 col5" >-0.104774</td>
#       <td id="T_a963f_row1_col6" class="data row1 col6" >-0.070660</td>
#       <td id="T_a963f_row1_col7" class="data row1 col7" >-0.091395</td>
#       <td id="T_a963f_row1_col8" class="data row1 col8" >0.362431</td>
#       <td id="T_a963f_row1_col9" class="data row1 col9" >-0.162865</td>
#       <td id="T_a963f_row1_col10" class="data row1 col10" >0.352288</td>
#     </tr>
#     <tr>
#       <th id="T_a963f_level0_row2" class="row_heading level0 row2" >housing_median_age</th>
#       <td id="T_a963f_row2_col0" class="data row2 col0" >-0.118552</td>
#       <td id="T_a963f_row2_col1" class="data row2 col1" >0.017276</td>
#       <td id="T_a963f_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_a963f_row2_col3" class="data row2 col3" >-0.356225</td>
#       <td id="T_a963f_row2_col4" class="data row2 col4" >-0.312179</td>
#       <td id="T_a963f_row2_col5" class="data row2 col5" >-0.296755</td>
#       <td id="T_a963f_row2_col6" c

# %%
Train.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  10371.000000  10371.000000        10371.000000  10371.000000
# mean    -119.576317     35.648347           28.707646   2631.445569
# std        1.997211      2.140070           12.631120   2173.616930
# min     -124.260000     32.560000            1.000000      8.000000
# 25%     -121.770000     33.940000           18.000000   1454.000000
# 50%     -118.510000     34.260000           29.000000   2126.000000
# 75%     -118.020000     37.730000           37.000000   3127.000000
# max     -114.310000     41.950000           52.000000  37937.000000
#
#        total_bedrooms    population    households  median_income  \
# count    10257.000000  10371.000000  10371.000000   10371.000000
# mean       537.541484   1426.518851    500.422524       3.868065
# std        425.582759   1137.463225    388.555637       1.885826
# min          1.000000      5.000000      1.000000       0.499900
# 25%        296.000000    791.000000    282.000000       2.556800
# 50%        435.000000   1163.000000    410.000000       3.534500
# 75%        640.000000   1719.000000    601.000000       4.747400
# max       6445.000000  28566.000000   6082.000000      15.000100
#
#        median_house_value  ocean_prox_inland  ocean_prox_nearocean  \
# count        10371.000000       10371.000000          10371.000000
# mean        206399.612284           0.323787              0.124771
# std         115215.425942           0.467943              0.330475
# min          14999.000000           0.000000              0.000000
# 25%         118750.000000           0.000000              0.000000
# 50%         179800.000000           0.000000              0.000000
# 75%         264000.000000           1.000000              0.000000
# max         500001.000000           1.000000              1.000000
#
#        ocean_prox_nearbay
# count        10371.000000
# mean             0.109247
# std              0.311964
# min              0.000000
# 25%              0.000000
# 50%              0.000000
# 75%              0.000000
# max              1.000000

# %% [markdown]
# ### We see that `total_bedrooms` has a few missing values, and it is also very correlated with `total_rooms`. Because of this, it's easiest to remove it from our training set.

# %%
indep_vars.remove("total_bedrooms")

# %% [markdown]
# ### We'll define some helper functions here:
# (1) to calculate MSE, and
# (2) to display the improvement of a GBM on test data as additional trees are constructed.

# %%
def mse(y, y_hat):
    """
    Calculate the MSE of a model given actual and predicted values
    """
    # calculate the residual error for each individual record
    resid = y - y_hat
    # square the residual (hence "squared error")
    sq_resid = resid**2
    # calculate the sum of squared errors
    SSR = sum(sq_resid)
    # divide by the number of records to get the mean squared error
    MSE = SSR / y.shape[0]
    return MSE

def gbm_progress(model_name, X_test, y_test):
    """
    Plot the 'progress' of a GBM on a test set to assess robustness
    """
    test_error = np.zeros_like(model_name.train_score_)
    for idx, y_ in enumerate(model_name.staged_predict(X_test)):
        test_error[idx] = np.mean((y_test - y_)**2)

    plot_idx = np.arange(model_name.train_score_.shape[0])
    ax = subplots(figsize=(8,8))[1]
    ax.plot(plot_idx,
            model_name.train_score_,
            'b',
            label='Training')
    ax.plot(plot_idx,
            test_error,
            'r',
            label='Test')
    ax.legend();

# %% [markdown]
# ### Build a basic GBM first.

# %%
# Documentation: https://scikit-learn.org/dev/modules/generated/sklearn.ensemble.GradientBoostingRegressor.html

gbm_basic = GBR(learning_rate=0.1,
               n_estimators=250,
               max_depth=10,
               min_samples_split=2,
               subsample=1,
               random_state=seed)

gbm_basic.fit(X_train[indep_vars], y_train)
# Out:
# GradientBoostingRegressor(max_depth=10, n_estimators=250, random_state=5151,
#                           subsample=1)

# %%
y_hat_basic = gbm_basic.predict(X_test[indep_vars])

mse_basic = mse(y_test, y_hat_basic)
print('test mse: ',mse_basic)
# Out:
# test mse:  2524578849.5044518

# %% [markdown]
# ### When we plot the performance of the model on training and test data, we see that performance no longer improves after a certain number of trees (in this case, between 50-100 trees).

# %%
gbm_progress(gbm_basic, X_test[indep_vars], y_test)

# %% [markdown]
# ### Now you'll have the chance to choose optimal hyperparameters to build a better GBM.
# Once the candidate hyperparameters are chosen, use 5-fold cross-validation to decide which collection of hyperparameters are best.

# %%
def get_best_gbm(X, y, results_path="gridsearch_results.pkl", force_retrain=False):
    """
    Runs GridSearchCV OR loads precomputed results if available.

    Parameters:
        X, y : training data
        results_path : where results are saved
        force_retrain : if True, ignore saved file and rerun

    Returns:
        best_model : fitted model
        best_params : dict
    """

    # Fast Version: load existing results
    if os.path.exists(results_path) and not force_retrain:
        data = joblib.load(results_path)
        print("Loaded precomputed GridSearchCV results.")
        return data["best_model"], data["best_params"]

    # Slow Version: run grid search via cross-validation
    print("Running GridSearchCV...")

    ## Define model
    gbm_cv = GBR(random_state=seed)

    ## Define hyperparameter grid. Choose between 1 and 4 values to test for each one.
    #fillin
    param_grid = {
        "n_estimators":[6000],
        "learning_rate": [0.01],
        "max_depth": [6],
        "min_samples_leaf": [5],
        "subsample": [0.8]
    }

    grid_search = GridSearchCV(
        estimator=gbm_cv,
        param_grid=param_grid,
        cv=5,                               # number of folds
        scoring="neg_mean_squared_error",   # how we evaluate which model is best
        n_jobs=-1,                          # use all available cores
        verbose=3
    )

    grid_search.fit(X, y)

    best_model = grid_search.best_estimator_
    best_params = grid_search.best_params_

    ## Save results. Gradescope will use this file instead of rerunning the grid search.
    joblib.dump({
        "best_model": best_model,
        "best_params": best_params,
        "cv_results": grid_search.cv_results_
    }, results_path)

    print(f"Saved results to {results_path}")

    return best_model, best_params

# %%
# Identify best model
best_model, best_params = get_best_gbm(X_train[indep_vars], y_train, force_retrain=False)

print("Best parameters:")
print(best_params)
# Out:
# Running GridSearchCV...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Saved results to gridsearch_results.pkl
# Best parameters:
# {'learning_rate': 0.01, 'max_depth': 6, 'min_samples_leaf': 5, 'n_estimators': 6000, 'subsample': 0.8}

# %% [markdown]
# ### Your grade on this assignment will be partially determined by the mean squared error on a separate holdout set. You can approximate this using the test set.

# %%
# Evaluate on test set 
y_pred = best_model.predict(X_test[indep_vars])
mse_best = mse(y_test, y_pred)

print("Test MSE:", mse_best)
# Out:
# Test MSE: 2127039167.0944052
